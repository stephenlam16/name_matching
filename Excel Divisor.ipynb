# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Divide

# %%
# Read the raw data file
df = pd.read_csv('maptool_excel_v2_withsectorinformation.CSV')

# %%
df.drop(columns=['majorindustrygroup'],axis=1,inplace=True)

# %%
chunk_size = 4000
output_folder = 'raw_data'

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

total_rows = len(df)
num_files = (total_rows // chunk_size) + 1

for i in range(num_files):
    start = i * chunk_size
    end = (i + 1) * chunk_size
    chunk_df = df[start:end]

    output_file = os.path.join(output_folder, f'data_section_{i+1}.csv')
    chunk_df.to_csv(output_file, index=False)

# %% [markdown]
# ## Combine

# %%
import os
import pandas as pd

def merge_excel_files(folder_path):
    all_data = pd.DataFrame()
    for file_name in os.listdir(folder_path):
        print(file_name)
        if file_name.endswith('.xlsx'):
            file_path = os.path.join(folder_path, file_name)
            df = pd.read_excel(file_path)
            all_data = all_data.append(df, ignore_index=True)
    return all_data

# %%
folder_path = 'matched_data/'
merged_data = merge_excel_files(folder_path)
# Out:
# Data_01_post.xlsx
# Data_02_post.xlsx
# Data_03_post.xlsx
# Data_04_post.xlsx
# Data_05_post.xlsx
# Data_06_post.xlsx
# Data_07_post.xlsx
# Data_08_post.xlsx
# Data_09_post.xlsx
# Data_10_post.xlsx
# Data_11_post.xlsx
# Data_12_post.xlsx
# Data_13_post.xlsx
# Data_14_post.xlsx
# Data_15_post.xlsx
# Data_16_post.xlsx
# Data_17_post.xlsx
# Data_18_post.xlsx
# Data_19_post.xlsx
# Data_20_post.xlsx
# Data_21_post.xlsx

# %%
merged_data
# Out:
#        Unnamed: 0                                   Processed Name  \
# 0               0     10 Federal Self Storage Acquisition 3 Co LLC
# 1               1                           1000137577 Ontario Inc
# 2               2                 1001 N Warson Property Owner LLC
# 3               3                                  1001 Office LLC
# 4               4                          1001-1037 Queensway Inc
# ...           ...                                              ...
# 82420        2420   Zhejiang Sanmei Real Estate Development Co Ltd
# 82421        2421  Zhejiang Shengxin Enterprise Development Co Ltd
# 82422        2422          Zhejiang Topsun Logistic Control Co Ltd
# 82423        2423               Zhejiang Valogin Technology Co Ltd
# 82424        2424                            Zoppas Industries SpA
#
#                                       processed_parent  borrowerid  \
# 0         10 Federal Self Storage Acquisition 3 Co LLC      165671
# 1                               1000137577 Ontario Inc      165057
# 2                     1001 N Warson Property Owner LLC      164426
# 3                                      1001 Office LLC      166800
# 4                              1001-1037 Queensway Inc      167597
# ...                                                ...         ...
# 82420   Zhejiang Sanmei Real Estate Development Co Ltd      127680
# 82421  Zhejiang Shengxin Enterprise Development Co Ltd      128508
# 82422          Zhejiang Topsun Logistic Control Co Ltd      128247
# 82423               Zhejiang Valogin Technology Co Ltd      128255
# 82424                            Zoppas Industries SpA      129199
#
#                                           borrowername          region  \
# 0         10 Federal Self Storage Acquisition 3 Co LLC      USA/Canada
# 1                               1000137577 Ontario Inc      USA/Canada
# 2                     1001 N Warson Property Owner LLC      USA/Canada
# 3                                      1001 Office LLC      USA/Canada
# 4                              1001-1037 Queensway Inc      USA/Canada
# ...                                                ...             ...
# 82420   Zhejiang Sanmei Real Estate Development Co Ltd    Asia Pacific
# 82421  Zhejiang Shengxin Enterprise Development Co Ltd    Asia Pacific
# 82422          Zhejiang Topsun Logistic Control Co Ltd    Asia Pacific
# 82423               Zhejiang Valogin Technology Co Ltd    Asia Pacific
# 82424                            Zoppas Industries SpA  Western Europe
#
#              country IQ_INDUSTRY_SECTOR  \
# 0      United States        Real Estate
# 1      United States             noinfo
# 2      United States        Real Estate
# 3      United States        Industrials
# 4             Canada          Utilities
# ...              ...                ...
# 82420          China        Real Estate
# 82421          India          Materials
# 82422          China          Materials
# 82423          China        Industrials
# 82424          Italy        Industrials
#
#                                                 parent parentticker  ...  \
# 0         10 Federal Self Storage Acquisition 3 Co LLC          NaN  ...
# 1                               1000137577 Ontario Inc          NaN  ...
# 2                     1001 N Warson Property Owner LLC          NaN  ...
# 3                                      1001 Office LLC          NaN  ...
# 4                              1001-1037 Queensway Inc          NaN  ...
# ...                                                ...          ...  ...
# 82420   Zhejiang Sanmei Real Estate Development Co Ltd          NaN  ...
# 82421  Zhejiang Shengxin Enterprise Development Co Ltd          NaN  ...
# 82422          Zhejiang Topsun Logistic Control Co Ltd          NaN  ...
# 82423               Zhejiang Valogin Technology Co Ltd          NaN  ...
# 82424                            Zoppas Industries SpA          NaN  ...
#
#       PAR_MATCH_ID5                 SECTOR1                 SECTOR2 SECTOR3  \
# 0               NaN                       0                     NaN     NaN
# 1               NaN                     NaN                     NaN     NaN
# 2               NaN                       0                     NaN     NaN
# 3               NaN              Financials                     NaN     NaN
# 4               NaN                       0  Consumer Discretionary       0
# ...             ...                     ...                     ...     ...
# 82420           NaN                     NaN                     NaN     NaN
# 82421           NaN                     NaN                     NaN     NaN
# 82422           NaN             Industrials                     NaN     NaN
# 82423           NaN             Industrials                     NaN     NaN
# 82424           NaN  Consumer Discretionary             Industrials       0
#
#       SECTOR4                 SECTOR5  \
# 0         NaN                     NaN
# 1         NaN                     NaN
# 2         NaN                     NaN
# 3         NaN                     NaN
# 4         NaN                     NaN
# ...       ...                     ...
# 82420     NaN                     NaN
# 82421     NaN                     NaN
# 82422     NaN                     NaN
# 82423     NaN                     NaN
# 82424       0  Consumer Discretionary
#
#                                          result_name     result_id state  \
# 0      10 Federal Self Storage Acquisition Co 3, LLC   IQ715057027     4
# 1                                                NaN           NaN    -1
# 2                 1001 N. Warson Property Owner, LLC  IQ1776238889     1
# 3                                   1001 Office, LLC  IQ1788563577     1
# 4                           1001-1037 Queensway Inc.  IQ1831365797     1
# ...                                              ...           ...   ...
# 82420                                            NaN           NaN    -1
# 82421                                            NaN           NaN    -1
# 82422     Zhejiang Topsun Logistic Control Co., Ltd.    IQ83967588     1
# 82423            Zhejiang Valogin Technology Co.,Ltd   IQ249811794     1
# 82424                          Zoppas Industries SpA   IQ129702638     1
#
#       matched_no
# 0              1
# 1            NaN
# 2              1
# 3              1
# 4              3
# ...          ...
# 82420        NaN
# 82421        NaN
# 82422          1
# 82423          1
# 82424          1
#
# [82425 rows x 50 columns]

# %%
output_path = 'combined_matched_data.xlsx'
merged_data.to_excel(output_path, index=False)
